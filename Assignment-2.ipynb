# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
## Univarient analysis

# %%
house = pd.read_csv('House_Price_India.csv')
house.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
house.shape
# Out:
# (14620, 23)

# %%
house.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %%
house.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
sns.histplot(x='living area', data=house);

# %%
sns.boxplot(x=house['lot area'])
# Out:
# <Axes: xlabel='lot area'>

# %%
df = house['waterfront present'].value_counts()
plt.pie(df, labels=df.index, autopct="%.0f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1e1ce923a00>,
# ...
#  [Text(-1.0996814455593686, 0.026471084081643635, '0'),
#   Text(1.0996814449010428, -0.026471111430289917, '1')],
#  [Text(-0.5998262430323829, 0.01443877313544198, '99%'),
#   Text(0.599826242673296, -0.014438788052885407, '1%')])

# %%
## Bivarient Analysis

# %%
h1 = pd.read_csv('House_Price_India.csv')
h1.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
x_a='living area'
y_a='lot area'

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=h1, x=x_a, y=y_a)
plt.title(f'Scatter Plot of {x_a} vs. {y_a}')
plt.xlabel(x_a)
plt.ylabel(y_a)
plt.show()

# %%
categorical_column = 'Built Year '
plt.figure(figsize=(8, 6))
sns.boxplot(data = h1, x='Built Year' , y='living area')
plt.title('Box Plot of living area by Built Year')
plt.xlabel('Built Year')
plt.ylabel('living area')
plt.show()

# %%
second_categorical_column = 'number of floors '
plt.figure(figsize=(10, 6))
sns.countplot(data=h1, x='Built Year', hue='number of floors')
plt.title(f'Count Plot of {categorical_column} by number of floors')
plt.xlabel('Built Year')
plt.ylabel('Count')
plt.legend(title='number of floors')
plt.show()

# %%
correlation_coefficient = h1[x_a].corr(h1[y_a])
print(f'Correlation coefficient between {x_a} and {y_a}: {correlation_coefficient}')
# Out:
# Correlation coefficient between living area and lot area: 0.17442007314085262

# %%
## Multivarient Analysis

# %%
house = pd.read_csv('House_Price_India.csv')
house.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
house.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
pd.plotting.scatter_matrix(house.loc[:, "Date":"Price"], diagonal="kde",figsize=(20,18))
plt.show()

# %%
ax = house[["Date","number of bedrooms","number of bathrooms","living area","lot area","number of floors","waterfront present","number of views","condition of the house","Built Year","Renovation Year","Postal Code","Longitude","Lattitude"]].plot(figsize=(20,15))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
X = house.loc[:, "Date":] # independent variables data
y = house.id
X.apply(np.max)
X.apply(np.min)
X.apply(np.mean)
X.apply(np.var)
X.apply(np.std)
# Out:
# Date                                         67.345688
# number of bedrooms                            0.938687
# number of bathrooms                           0.769908
# living area                                 928.243974
# lot area                                  37918.324441
# number of floors                              0.540220
# waterfront present                            0.087190
# number of views                               0.766232
# condition of the house                        0.664128
# grade of the house                            1.174993
# Area of the house(excluding basement)       833.781447
# Area of the basement                        448.536068
# Built Year                                   29.492616
# Renovation Year                             416.202427
# Postal Code                                  19.081765
# Lattitude                                     0.137517
# Longitude                                     0.141321
# ...

# %%
## Descriptive statistics on the dataset.

# %%
summary_stats = house.describe()
print(summary_stats)
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
means = house.mean()
means
# Out:
# id                                       6.762821e+09
# Date                                     4.260454e+04
# number of bedrooms                       3.379343e+00
# number of bathrooms                      2.129583e+00
# living area                              2.098263e+03
# lot area                                 1.509328e+04
# number of floors                         1.502360e+00
# waterfront present                       7.660739e-03
# number of views                          2.331053e-01
# condition of the house                   3.430506e+00
# grade of the house                       7.682421e+00
# Area of the house(excluding basement)    1.801784e+03
# Area of the basement                     2.964791e+02
# Built Year                               1.970926e+03
# Renovation Year                          9.092401e+01
# Postal Code                              1.220331e+05
# Lattitude                                5.279285e+01
# ...

# %%
medians = house.median()
medians
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...

# %%
modes = house.mode()
modes
# Out:
#                id     Date  number of bedrooms  number of bathrooms  \
# 0      6762810020  42543.0                 3.0                  2.5
# 1      6762810021      NaN                 NaN                  NaN
# 2      6762810022      NaN                 NaN                  NaN
# 3      6762810023      NaN                 NaN                  NaN
# 4      6762810026      NaN                 NaN                  NaN
# ...           ...      ...                 ...                  ...
# 14615  6762831611      NaN                 NaN                  NaN
# 14616  6762831612      NaN                 NaN                  NaN
# 14617  6762831613      NaN                 NaN                  NaN
# 14618  6762831615      NaN                 NaN                  NaN
# 14619  6762831616      NaN                 NaN                  NaN
#
#        living area  lot area  number of floors  waterfront present  \
# 0           1400.0    5000.0               1.0                 0.0
# ...

# %%
std_dev = house.std()
std_dev
# Out:
# id                                         6237.574799
# Date                                         67.347991
# number of bedrooms                            0.938719
# number of bathrooms                           0.769934
# living area                                 928.275721
# lot area                                  37919.621304
# number of floors                              0.540239
# waterfront present                            0.087193
# number of views                               0.766259
# condition of the house                        0.664151
# grade of the house                            1.175033
# Area of the house(excluding basement)       833.809963
# Area of the basement                        448.551409
# Built Year                                   29.493625
# Renovation Year                             416.216661
# Postal Code                                  19.082418
# Lattitude                                     0.137522
# ...

# %%
variance = house.var()
variance
# Out:
# id                                       3.890734e+07
# Date                                     4.535752e+03
# number of bedrooms                       8.811931e-01
# number of bathrooms                      5.927991e-01
# living area                              8.616958e+05
# lot area                                 1.437898e+09
# number of floors                         2.918578e-01
# waterfront present                       7.602572e-03
# number of views                          5.871521e-01
# condition of the house                   4.410968e-01
# grade of the house                       1.380702e+00
# Area of the house(excluding basement)    6.952391e+05
# Area of the basement                     2.011984e+05
# Built Year                               8.698739e+02
# Renovation Year                          1.732363e+05
# Postal Code                              3.641387e+02
# Lattitude                                1.891231e-02
# ...

# %%
quantiles = house.quantile([0.25, 0.75])  
quantiles
# Out:
#                 id     Date  number of bedrooms  number of bathrooms  \
# 0.25  6.762815e+09  42546.0                 3.0                 1.75
# 0.75  6.762826e+09  42662.0                 4.0                 2.50
#
#       living area  lot area  number of floors  waterfront present  \
# 0.25       1440.0   5010.75               1.0                 0.0
# 0.75       2570.0  10800.00               2.0                 0.0
#
#       number of views  condition of the house  ...  Built Year  \
# 0.25              0.0                     3.0  ...      1951.0
# 0.75              0.0                     4.0  ...      1997.0
#
#       Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0.25              0.0     122017.0    52.7076   -114.519             1490.0
# 0.75              0.0     122048.0    52.9089   -114.315             2380.0
#
#       lot_area_renov  Number of schools nearby  Distance from the airport  \
# ...

# %%
counts = house.count()
counts
# Out:
# id                                       14620
# Date                                     14620
# number of bedrooms                       14620
# number of bathrooms                      14620
# living area                              14620
# lot area                                 14620
# number of floors                         14620
# waterfront present                       14620
# number of views                          14620
# condition of the house                   14620
# grade of the house                       14620
# Area of the house(excluding basement)    14620
# Area of the basement                     14620
# Built Year                               14620
# Renovation Year                          14620
# Postal Code                              14620
# Lattitude                                14620
# Longitude                                14620
# living_area_renov                        14620
# lot_area_renov                           14620
# ...

# %%
correlation_matrix = house.corr()
correlation_matrix
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
## Missing Value Handling

# %%
null_house = house.isnull()
null_house
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0      False  False               False                False        False
# 1      False  False               False                False        False
# 2      False  False               False                False        False
# 3      False  False               False                False        False
# 4      False  False               False                False        False
# ...      ...    ...                 ...                  ...          ...
# 14615  False  False               False                False        False
# 14616  False  False               False                False        False
# 14617  False  False               False                False        False
# 14618  False  False               False                False        False
# 14619  False  False               False                False        False
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
null_summary = null_house.sum()
null_summary
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
## So there are no null values in dataset
